# %% [markdown]
# - Entendimento inicial de relação entre dados;
# - Data Cleaning
# - Data Transformation:
#     - Transformar aplicando a função a um atributo
#     - Sumarizando "Grouping"
#     - Discretization/Discretização
#         - Transformação de valores numéricos em valores categóricos
#         - Binarizing
#         - Binning
#     - "Handle" de valores perdidos
#     - "Standerdization"
#     - Normalização
#
# - (...)

# %% [markdown]
# Ver alguma coisa sobre "Broadcasting"

# %% [markdown]
# # NumPy

# %%
import numpy as np

a = np.array([1,2,3])
print(f"Size: {a.size}, Dimensions: {a.ndim}, Shape: {a.shape}")
print(a[np.newaxis, :], a[:, np.newaxis], sep = '\n\n')

# %%
A = np.arrange(1,10).reshape(3,3)  
B = np.arrange(12).reshape(3,4)
C = np.array([1,3,7,2,1,9,5,2,8]).reshape(3,3)
I = np.eye(3)
UM = np.eye(5)
ZERO = np.zeros((4,4))
D = np.array([9,8,5])
UM
